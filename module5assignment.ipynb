# %%
#Dependecies from a list of dictionaries 
import pandas as pd

# %%
raw_data_info = {
    
        "Unique Mouse ID" : ["a203", "a251", "a262", "a275", "a366", "a401", "a411", "a444", "a457", "a492", "a520", "a577", "a644","a685", "a699", "a788", "a818", "a897", "a963", "b128", "b313", "b447", "b487", "b559",
                             "b742", "b759", "b879", "c139", "c264", "c282", "c302", "c326", "c402", "c458", "c559", "c580","c757", "c758", "c766", "c819","c832", "c895", "c927", "d133", "d164", "d251", "d474", "e213","e227", "e291", "e476", "e584", "e662", "f129","f234", "f278", "f345", "f394", "f436", "f545", 
                             "f932", "f966", "f993", "g107", "g288", "g296","g316", "g497", "g558", "g570", "g791", "g867","g989", "h246", "h333", "h428", "h531", "i177","i334", "i386", "i477", "i557", "i635", "i669", 
                             "i738", "i901", "j119", "j235", "j246", "j296","j365", "j755", "j913", "j984", "j989", "k210", 
                             "k382", "k403", "k483", "k510", "k603", "k754", "k804","k862", "k894", "l215", "l264", "l471", "l490",
                             "l509", "l558", "l661", "l700", "l725", "l733","l872", "l897", "m133", "m269", "m331", "m546", "m550", "m601", "m650", "m756", "m957", "n304","n364", "n482", "n630", "n671", "n678", "n763", 
                             "n923", "n967", "o287", "o302", "o331", "o523","o562", "o725", "o795", "o809", "o813", "o848", "o926", "o973", "p136", "p189", "p310", "p387","p438", "p981", "q119", "q132", "q483", "q511", 
                             "q582", "q597", "q610", "q633", "q787", "r107","r157", "r554", "r604", "r701", "r811", "r850","r921", "r944", "s121", "s141", "s152", "s166","s185", "s187", "s337", "s508", "s565", "s619",
                             "s710", "t198", "t451", "t565", "t573", "t718","t724", "t994", "u149", "u153", "u196", "u327","u364", "u946", "v199", "v289", "v295", "v339","v409", "v603", "v719", "v764", "v766", "v835",
                             "v923", "v989", "v991", "w140", "w150", "w151","w167", "w193", "w350", "w422", "w540", "w575", "w584", "w678", "w697", "w746", "w914","x111", "x209", "x226", "x264", "x336", "x401", "x402",
                             "x581", "x613", "x773", "x822", "x930", "y163","y260", "y449", "y478", "y601", "y769", "y793", "y865", "z234", "z314", "z435", "z578", "z581","z795", "z969"],
    
    "Sex": ["Female", "Female", "Female","Female", "Female", "Female", "Male", "Female","Female", "Male", "Male", "Female", "Female", "Male", "Female", "Male", "Female",
    "Male", "Female", "Female", "Male", "Male", "Female", "Male", "Male", "Female", "Female","Male", "Female","Male", "Female", "Female", "Female", "Female", "Female", "Male", "Male", "Male",
"Female", "Male", "Male", "Female", "Female", "Male", "Male", "Female", "Male", "Male", "Male","Female", "Male", "Male", "Male", "Female", "Male", "Male","Male", "Male", "Female", "Female", "Male", "Male",
"Male", "Female", "Male", "Female", "Female","Male", "Male", "Male", "Male", "Female", "Female", "Male", "Male","Female", "Male", "Male", "Female", "Female", "Female", "Female", "Male","Female", "Female", "Male", "Female",
"Male", "Female", "Female", "Male", "Male", "Female", "Female", "Male", "Male", "Male", "Male", "Female","Female", "Male", "Female", "Female", "Female", "Female", "Male", "Female", "Female", "Male", "Male", "Female",
"Male", "Female", "Female", "Female", "Male", "Male", "Female", "Female", "Female", "Male", "Male", "Male","Male", "Male", "Female", "Male", "Male", "Female", "Female", "Male", "Male", "Female", "Male", "Male",
"Male", "Female", "Male", "Female", "Female", "Male", "Female", "Male", "Male", "Female", "Male", "Female","Female", "Male", "Male", "Male", "Female", "Male", "Male", "Female", "Male", "Female", "Male", "Male", "Female",
"Male", "Male", "Female", "Male", "Female", "Male", "Male", "Male", "Male", "Female", "Male", "Male", "Male","Female", "Male", "Female", "Male", "Male", "Male", "Female", "Male", "Female", "Male", "Male",
"Female", "Female", "Female", "Female", "Male", "Male", "Female", "Male", "Male", "Male", "Male", "Female", "Female","Female", "Male", "Female", "Female", "Female", "Female", "Male", "Male", "Female", "Male", "Female", "Female",
"Male", "Male", "Female", "Male", "Male", "Female", "Female", "Female", "Male", "Female", "Female", "Male", "Male", "Female","Female", "Male", "Female", "Female", "Female", "Male", "Female", "Female", "Female", "Male", "Male", "Female", "Female",
"Male", "Female", "Female", "Female", "Male", "Male", "Female", "Female", "Female", "Male", "Female", "Female", "Male"],
 
    "Drug" : ["Infubinol", "Infubinol", "Placebo", "Ceftamin", "Stelasyn", "Zoniferol", "Ramicane", "Ramicane", "Ketapril", "Stelasyn", "Ramicane", "Infubinol", "Ramicane", "Infubinol", "Propriva", "Zoniferol", "Naftisol", "Placebo", "Stelasyn","Capomulin",
"Zoniferol", "Ceftamin", "Ceftamin", "Naftisol", "Capomulin", "Ceftamin", "Stelasyn", "Infubinol", "Zoniferol", "Placebo","Zoniferol", "Infubinol", "Stelasyn", "Ramicane", "Zoniferol", "Ketapril", "Placebo", "Ramicane", "Placebo", "Ketapril","Ketapril", "Infubinol", "Propriva", 
"Zoniferol", "Zoniferol", "Ramicane", "Ketapril", "Naftisol", "Placebo", "Naftisol","Infubinol", "Naftisol", "Ramicane", "Zoniferol", "Stelasyn", "Ketapril", "Infubinol", "Zoniferol", "Ceftamin", "Zoniferol","Ketapril", "Capomulin", "Naftisol", "Ketapril", "Capomulin", 
"Zoniferol", "Capomulin", "Ketapril", "Propriva", "Propriva","Ramicane", "Stelasyn", "Propriva", "Ketapril", "Stelasyn", "Ketapril", "Ceftamin", "Ramicane", "Ramicane", "Infubinol","Placebo", "Capomulin", "Propriva", "Placebo", "Capomulin", "Stelasyn", "Capomulin", "Placebo", "Capomulin",
"Ceftamin", "Zoniferol","Naftisol", "Ramicane", "Stelasyn", "Ramicane", "Ceftamin", "Ketapril", "Ramicane", "Infubinol", "Stelasyn", "Propriva", "Zoniferol","Infubinol", "Stelasyn", "Zoniferol", "Propriva", "Ketapril", "Ceftamin", "Ceftamin", "Capomulin", "Ceftamin", "Ceftamin", "Naftisol", "Naftisol", "Ceftamin", "Placebo", "Capomulin", 
"Naftisol", "Stelasyn", "Zoniferol", "Ramicane", "Ketapril", "Capomulin","Ketapril", "Infubinol", "Capomulin","Naftisol", "Ramicane", "Propriva", "Propriva", "Infubinol", "Propriva", "Placebo", "Ketapril",
"Zoniferol", "Ceftamin", "Placebo", "Ketapril", "Propriva", "Propriva", "Naftisol", "Placebo", "Infubinol", "Infubinol", "Stelasyn",
"Zoniferol", "Ketapril", "Zoniferol", "Ketapril", "Propriva", "Stelasyn", "Ceftamin", "Stelasyn", "Ketapril", "Infubinol", "Ceftamin", "Zoniferol", "Placebo", "Ramicane", "Ramicane", "Zoniferol", "Placebo", "Propriva", "Capomulin", "Capomulin", "Naftisol", "Naftisol", "Ramicane", "Placebo", "Ramicane", 
"Capomulin", "Infubinol", "Propriva", "Placebo", "Placebo", "Capomulin", "Propriva", "Zoniferol", "Ramicane","Stelasyn", "Stelasyn", "Capomulin", "Propriva", "Stelasyn", "Capomulin", "Ceftamin", "Placebo", "Naftisol", "Placebo", "Ceftamin", "Ceftamin", "Ramicane", "Ketapril", "Capomulin", "Propriva", "Naftisol", 
"Ketapril", "Naftisol", "Infubinol", "Placebo", "Ketapril", "Infubinol", "Stelasyn", "Infubinol", "Naftisol", "Capomulin", "Placebo", "Propriva", "Zoniferol", 
"Capomulin", "Ceftamin", "Placebo", "Infubinol", "Propriva", "Ketapril", "Stelasyn", "Zoniferol", "Infubinol", "Ramicane", "Stelasyn", "Propriva", "Capomulin",
"Propriva", "Propriva", "Ceftamin", "Naftisol", "Naftisol", "Capomulin", "Stelasyn", "Ceftamin", "Zoniferol", "Placebo", "Ceftamin", "Naftisol", "Infubinol", "Ketapril","Ramicane", "Placebo", "Naftisol", "Ceftamin", "Capomulin", "Ceftamin", "Naftisol", "Stelasyn", "Propriva", "Ramicane", "Infubinol", "Naftisol", "Naftisol"],
}

info_df = pd.DataFrame (raw_data_info, columns = ["Unique Mouse ID", "Sex", "Drug"])
info_df
# Out:
#     Unique Mouse ID     Sex       Drug
# 0              a203  Female  Infubinol
# 1              a251  Female  Infubinol
# 2              a262  Female    Placebo
# 3              a275  Female   Ceftamin
# 4              a366  Female   Stelasyn
# ..              ...     ...        ...
# 244            z435  Female   Propriva
# 245            z578    Male   Ramicane
# 246            z581  Female  Infubinol
# 247            z795  Female   Naftisol
# 248            z969    Male   Naftisol
#
# [249 rows x 3 columns]

# %%
#Dependecies out of a list of dictionaries
import pandas as pd

# %%
 #Create Statistics 
drugdatainfo_df = pd.DataFrame ([
    
{"Drug" : "Capomulin", "Unique Mouse ID" : ("s185", "x401", "m601", "f966", "u364", "y793", "r554", "m957", "t565", "i738", "w914", "g288", "l897", "b742", "b128",
"j246", "j119", "w150", "v923", "g316", "s710", "l509", "r944", "i557", "r157"), "Median" : "51.61838657", "Mean" : "50.95821515", "Variance" : "108.6138903"}, "Standard Deviation": "
 
{"Drug": "Certamin", "Unique Mouse ID" : ("a275", "b447", "b487", "b759", "f436", "h531", "j296", "k210", "l471", "l490", "l558", "l661", "l733", "o287", "p438", "q483",
"t573", "u149", "u153", "w151", "x226", "x581", "x822", "y769", "y865"), "Median": "47.15443254", "Mean" : "50.71336327", "Variance" : "83.36174789"}, "Standard Deviation" : 

  {"Drug": "Infubinol", "Unique Mouse ID": ("a203","a251","a577","a685","c139","c326","c895","e476","f345","i386","k483","k804", "m756", "n671" ,"o809","o813","q132",
"s121","v339", "v719", "v766", "w193", "w584", "y163", "z581"), "Median" : "49.5096389", "Mean" : "51.04541265", "Variance" : "56.29033424"},

{"Drug": "Ketapril", "Unique Mouse ID": ("a457", "c580", "c819", "c832", "d474", "f278", "f932", "g107", "g497", "h246", "h428", "k382", "l264", "m550", "m650", "n923", "o331",
"o973", "p189", "q119", "u327", "v289", "v603", "w422", "y260"), "Median" : "49.79091948", "Mean" : "51.25848911", "Variance" : "87.28506333"},
    
{"Drug": "Naftisol", "Unique Mouse ID": ("a818", "b559", "e213", "e291", "e584", "f993", "j755", "l700", "l725", "m133", "n304", "o725", "r604", "r701", "t724", "v199", "v295",
"v835", "x264", "x336", "x930", "y601", "z234", "z795", "z969"), "Median" : "50.33894583", "Mean" : "51.66078546", "Variance" : "88.84103992"},
    
{"Drug": "Placebo", "Unique Mouse ID": ("a262", "a897", "c282", "c757", "c766", "e227", "i477", "i669", "j235", "l872", "n763","o302", "o795", "q582", "q787", "r850", "s152",
"s166", "t718", "t994", "v409", "v989", "w167", "x773", "y478"), "Median" : "52.34308525", "Mean" : "54.24721306", "Variance" : "83.61306176"},

{"Drug": "Propriva", "Unique Mouse ID": ("a699", "c927", "g558","g570", "g989", "i635", "k603", "l215", "n482", "n630", "n678", "o523", "o562", "p310", "r107", "s141",
"s187", "t198", "u946", "v991", "w350", "w746", "x111", "x209", "z435"), "Median" : "48.43219661", "Mean" : "49.4586671", "Variance" : "43.80315588"},

{"Drug": "Ramicane", "Unique Mouse ID": ("k403", "g791","s508", "m546", "z578", "j913", "n364", "c758", "a644", "i177", "j989", "a520", "r811", "i334", "q610", "d251",
"c458", "a411", "e662", "u196", "q597", "a444", "r921", "w678", "y449"), "Median" : "48.00919049", "Mean" : "48.65096405", "Variance" : "48.59076428"},
    
  {"Drug": "Stelasyn", "Unique Mouse ID": ("a366", "a492", "a963", "b879", "c402", "f234", "g867", "h333", "i901", "j984", "k510", "k862", "m269", "o848", "p387", "p981",
"s565", "s619", "t451", "v764", "w540", "w697", "x402", "z314"), "Median" : "50.02418081", "Mean" : "51.54565333", "Variance" : "119.7978363"},
 
  {"Drug": "Zoniferol", "Unique Mouse ID": ("a401", "a788", "b313", "c264", "c302", "c559", "d133", "d164", "f129", "f394", "f545", "g296", "j365", "k754", "k894", "m331",
"n967", "o926", "p136", "q511", "q633", "s337", "w140", "w575", "x613"), "Median" : "47.97292708", "Mean" : "50.26052286", "Variance" : "59.23171811"},
 
           
])

drugdatainfo_df
# Out:
#         Drug                                    Unique Mouse ID       Median  \
# 0  Capomulin  (s185, x401, m601, f966, u364, y793, r554, m95...  51.61838657
# 1   Certamin  (a275, b447, b487, b759, f436, h531, j296, k21...  47.15443254
# 2  Infubinol  (a203, a251, a577, a685, c139, c326, c895, e47...   49.5096389
# 3   Ketapril  (a457, c580, c819, c832, d474, f278, f932, g10...  49.79091948
# 4   Naftisol  (a818, b559, e213, e291, e584, f993, j755, l70...  50.33894583
# 5    Placebo  (a262, a897, c282, c757, c766, e227, i477, i66...  52.34308525
# 6   Propriva  (a699, c927, g558, g570, g989, i635, k603, l21...  48.43219661
# 7   Ramicane  (k403, g791, s508, m546, z578, j913, n364, c75...  48.00919049
# 8   Stelasyn  (a366, a492, a963, b879, c402, f234, g867, h33...  50.02418081
# 9  Zoniferol  (a401, a788, b313, c264, c302, c559, d133, d16...  47.97292708
#
#           Mean     Variance
# 0  50.95821515  108.6138903
# 1  50.71336327  83.36174789
# 2  51.04541265  56.29033424
# ...

# %%
#Merge two dataframes using an inner join 
merge_df = pd.merge (info_df, mouse_id_df, on = "Unique Mouse ID")
merge_df
# Out:
#     Unique Mouse ID     Sex       Drug Timepoint Tumor Volume Metastatic
# 0              a203  Female  Infubinol        10   51.8524372          1
# 1              a251  Female  Infubinol        10  48.59117901          1
# 2              a262  Female    Placebo        10  49.59518129          1
# 3              a275  Female   Ceftamin        10  47.37134328          0
# 4              a366  Female   Stelasyn        10  53.52399007          0
# ..              ...     ...        ...       ...          ...        ...
# 229            z435  Female   Propriva        10  48.71066147          0
# 230            z578    Male   Ramicane        10  42.95211843          0
# 231            z581  Female  Infubinol        10  50.47875016          2
# 232            z795  Female   Naftisol        10   48.0308039          0
# 233            z969    Male   Naftisol        10  52.65608148          1
#
# [234 rows x 6 columns]

# %%
 #Create bar chart

mouse_id_df = pd.DataFrame ([
{"Unique Mouse ID" : "a203", "Timepoint" : "10", "Tumor Volume" : "51.8524372" , "Metastatic": "1"}, {"Unique Mouse ID" : "a251", "Timepoint" : "10", "Tumor Volume" : "48.59117901" , "Metastatic": "1"},
{"Unique Mouse ID" : "a262", "Timepoint" : "10", "Tumor Volume" : "49.59518129", "Metastatic" : "1"},{"Unique Mouse ID" : "a275", "Timepoint" : "10", "Tumor Volume" : "47.37134328", "Metastatic": "0"},
{"Unique Mouse ID" : "a366", "Timepoint" : "10", "Tumor Volume" : "53.52399007" , "Metastatic": "0"},{"Unique Mouse ID" : "a401", "Timepoint" : "10", "Tumor Volume" : "47.7259374", "Metastatic" : "1"},
{"Unique Mouse ID" : "a411", "Timepoint" : "10", "Tumor Volume" : "40.75978762" , "Metastatic": "1"},{"Unique Mouse ID" : "a444", "Timepoint" : "10", "Tumor Volume" : "44.51255951" , "Metastatic": "0"},
{"Unique Mouse ID" : "a457", "Timepoint" : "10", "Tumor Volume" : "49.78341894", "Metastatic" : "0"},{"Unique Mouse ID" : "a492", "Timepoint" : "10", "Tumor Volume" : "48.43219661" , "Metastatic": "0"},
{"Unique Mouse ID" : "a520", "Timepoint" : "10", "Tumor Volume" : "36.42938781" , "Metastatic": "0"},{"Unique Mouse ID" : "a577", "Timepoint" : "10", "Tumor Volume" : "49.5096389", "Metastatic" : "1"},
{"Unique Mouse ID" : "a644", "Timepoint" : "10", "Tumor Volume" : "46.38071258" , "Metastatic": "0"},{"Unique Mouse ID" : "a699", "Timepoint" : "10", "Tumor Volume" : "47.86737569" , "Metastatic": "0"},
{"Unique Mouse ID" : "a788", "Timepoint" : "10", "Tumor Volume" : "50.15972132", "Metastatic" : "1"},{"Unique Mouse ID" : "a818", "Timepoint" : "10", "Tumor Volume" : "49.79091948" , "Metastatic": "0"},
{"Unique Mouse ID" : "a897", "Timepoint" : "10", "Tumor Volume" : "47.97292708" , "Metastatic": "1"},{"Unique Mouse ID" : "a963", "Timepoint" : "10", "Tumor Volume" : "47.15052201", "Metastatic" : "0"},
{"Unique Mouse ID" : "b128", "Timepoint" : "10", "Tumor Volume" : "43.2708519" , "Metastatic": "0"},{"Unique Mouse ID" : "b313", "Timepoint" : "10", "Tumor Volume" : "48.31937218", "Metastatic" : "1"},
{"Unique Mouse ID" : "b447", "Timepoint" : "0", "Tumor Volume" : "45" , "Metastatic": "0"},{"Unique Mouse ID" : "b559", "Timepoint" : "10", "Tumor Volume" : "48.03643202" , "Metastatic": "0"},
{"Unique Mouse ID" : "b742", "Timepoint" : "10", "Tumor Volume" : "41.99922813" , "Metastatic": "1"},{"Unique Mouse ID" : "b759", "Timepoint" : "10", "Tumor Volume" : "49.13335499", "Metastatic" : "0"},
{"Unique Mouse ID" : "b879", "Timepoint" : "10", "Tumor Volume" : "50.33894583", "Metastatic": "1"},{"Unique Mouse ID" : "c139", "Timepoint" : "10", "Tumor Volume" : "49.99295391" , "Metastatic": "0"},
{"Unique Mouse ID" : "c264", "Timepoint" : "10", "Tumor Volume" : "49.02659196", "Metastatic" : "0"},{"Unique Mouse ID" : "c282", "Timepoint" : "10", "Tumor Volume" : "48.17950638" , "Metastatic": "0"},
{"Unique Mouse ID" : "c302", "Timepoint" : "10", "Tumor Volume" : "48.53356704" , "Metastatic": "1"},{"Unique Mouse ID" : "c326", "Timepoint" : "0", "Tumor Volume" : "45", "Metastatic" : "0"},
{"Unique Mouse ID" : "c402", "Timepoint" : "10", "Tumor Volume" : "50.56689412" , "Metastatic": "1"},{"Unique Mouse ID" : "c458", "Timepoint" : "10", "Tumor Volume" : "44.45437828" , "Metastatic": "1"},
{"Unique Mouse ID" : "c559", "Timepoint" : "10", "Tumor Volume" : "47.29326012", "Metastatic" : "0"},{"Unique Mouse ID" : "c580", "Timepoint" : "10", "Tumor Volume" : "47.57017382" , "Metastatic": "1"},
{"Unique Mouse ID" : "c757", "Timepoint" : "10", "Tumor Volume" : "49.21931669" , "Metastatic": "0"},{"Unique Mouse ID" : "c758", "Timepoint" : "10", "Tumor Volume" : "46.28799223", "Metastatic" : "0"},
{"Unique Mouse ID" : "c766", "Timepoint" : "10", "Tumor Volume" : "49.50027098" , "Metastatic": "1"},{"Unique Mouse ID" : "c819", "Timepoint" : "10", "Tumor Volume" : "46.65839527" , "Metastatic": "1"},
{"Unique Mouse ID" : "c832", "Timepoint" : "10", "Tumor Volume" : "49.81141262", "Metastatic" : "1"},{"Unique Mouse ID" : "c895", "Timepoint" : "10", "Tumor Volume" : "49.77901542" , "Metastatic": "0"},
{"Unique Mouse ID" : "c927", "Timepoint" : "10", "Tumor Volume" : "50.96529767", "Metastatic" : "1"},{"Unique Mouse ID" : "d133", "Timepoint" : "0", "Tumor Volume" : "45" , "Metastatic": "0"},    
   
{"Unique Mouse ID" : "d146", "Timepoint" : "10", "Tumor Volume" : "47.47464468" , "Metastatic": "1"},{"Unique Mouse ID" : "d251", "Timepoint" : "10", "Tumor Volume" : "42.43225791", "Metastatic" : "1"},
{"Unique Mouse ID" : "d474", "Timepoint" : "10", "Tumor Volume" : "46.97496297", "Metastatic": "0"},{"Unique Mouse ID" : "e213", "Timepoint" : "10", "Tumor Volume" : "47.3915712" , "Metastatic": "2"},
{"Unique Mouse ID" : "e227", "Timepoint" : "10", "Tumor Volume" : "51.34975705", "Metastatic" : "1"},{"Unique Mouse ID" : "e291", "Timepoint" : "10", "Tumor Volume" : "48.52974125" , "Metastatic": "1"},
{"Unique Mouse ID" : "e476", "Timepoint" : "10", "Tumor Volume" : "49.43168536" , "Metastatic": "0"},{"Unique Mouse ID" : "e584", "Timepoint" : "0", "Tumor Volume" : "47.25064148", "Metastatic" : "0"},
{"Unique Mouse ID" : "e662", "Timepoint" : "10", "Tumor Volume" : "46.40908385" , "Metastatic": "0"},{"Unique Mouse ID" : "f129", "Timepoint" : "10", "Tumor Volume" : "48.17971908" , "Metastatic": "0"},
{"Unique Mouse ID" : "f234", "Timepoint" : "10", "Tumor Volume" : "47.90432375", "Metastatic" : "0"},{"Unique Mouse ID" : "f345", "Timepoint" : "10", "Tumor Volume" : "47.22244619" , "Metastatic": "0"},
{"Unique Mouse ID" : "f436", "Timepoint" : "10", "Tumor Volume" : "48.14697758" , "Metastatic": "2"},{"Unique Mouse ID" : "f545", "Timepoint" : "10", "Tumor Volume" : "51.07251225", "Metastatic" : "0"},
{"Unique Mouse ID" : "f966", "Timepoint" : "10", "Tumor Volume" : "35.6244027" , "Metastatic": "0"},{"Unique Mouse ID" : "f993", "Timepoint" : "10", "Tumor Volume" : "48.18537323" , "Metastatic": "0"},
{"Unique Mouse ID" : "g107", "Timepoint" : "10", "Tumor Volume" : "53.43598668", "Metastatic" : "0"},{"Unique Mouse ID" : "g288", "Timepoint" : "10", "Tumor Volume" : "46.30400254" , "Metastatic": "1"},
{"Unique Mouse ID" : "g296", "Timepoint" : "10", "Tumor Volume" : "48.26950861", "Metastatic" : "0"},{"Unique Mouse ID" : "g316", "Timepoint" : "10", "Tumor Volume" : "44.50204246" , "Metastatic": "0"},   
   
{"Unique Mouse ID" : "g497", "Timepoint" : "10", "Tumor Volume" : "49.6470865" , "Metastatic": "0"},{"Unique Mouse ID" : "g558", "Timepoint" : "10", "Tumor Volume" : "50.09475382", "Metastatic" : "0"},
{"Unique Mouse ID" : "g570", "Timepoint" : "10", "Tumor Volume" : "49.18823167", "Metastatic": "1"},{"Unique Mouse ID" : "g791", "Timepoint" : "10", "Tumor Volume" : "40.17055848" , "Metastatic": "0"},
{"Unique Mouse ID" : "g867", "Timepoint" : "10", "Tumor Volume" : "48.18340167", "Metastatic" : "0"},{"Unique Mouse ID" : "g989", "Timepoint" : "10", "Tumor Volume" : "51.74515613" , "Metastatic": "0"},
{"Unique Mouse ID" : "g989", "Timepoint" : "10", "Tumor Volume" : "49.8805278" , "Metastatic": "0"},{"Unique Mouse ID" : "h246", "Timepoint" : "10", "Tumor Volume" : "51.36886216", "Metastatic" : "1"},
{"Unique Mouse ID" : "h333", "Timepoint" : "10", "Tumor Volume" : "46.23384414" , "Metastatic": "1"},{"Unique Mouse ID" : "i777", "Timepoint" : "10", "Tumor Volume" : "41.02092924" , "Metastatic": "0"},
{"Unique Mouse ID" : "i334", "Timepoint" : "10", "Tumor Volume" : "41.63124731", "Metastatic" : "0"},{"Unique Mouse ID" : "i386", "Timepoint" : "10", "Tumor Volume" : "49.86154739" , "Metastatic": "2"},
{"Unique Mouse ID" : "i477", "Timepoint" : "10", "Tumor Volume" : "47.52063206" , "Metastatic": "0"},{"Unique Mouse ID" : "i557", "Timepoint" : "10", "Tumor Volume" : "42.99207658", "Metastatic" : "0"},
{"Unique Mouse ID" : "i635", "Timepoint" : "10", "Tumor Volume" : "48.68575605" , "Metastatic": "1"},{"Unique Mouse ID" : "i669", "Timepoint" : "10", "Tumor Volume" : "48.2816334" , "Metastatic": "1"},
{"Unique Mouse ID" : "i738", "Timepoint" : "10", "Tumor Volume" : "43.42101414", "Metastatic" : "0"},{"Unique Mouse ID" : "i901", "Timepoint" : "10", "Tumor Volume" : "50.42124982" , "Metastatic": "0"},
{"Unique Mouse ID" : "j119", "Timepoint" : "10", "Tumor Volume" : "46.42536551", "Metastatic" : "0"},{"Unique Mouse ID" : "j235", "Timepoint" : "10", "Tumor Volume" : "48.01878792" , "Metastatic": "1"},   

{"Unique Mouse ID" : "j246", "Timepoint" : "10", "Tumor Volume" : "46.4083613" , "Metastatic": "0"},{"Unique Mouse ID" : "j296", "Timepoint" : "10", "Tumor Volume" : "48.52997762", "Metastatic" : "2"},
{"Unique Mouse ID" : "j365", "Timepoint" : "10", "Tumor Volume" : "48.34932028", "Metastatic": "0"},{"Unique Mouse ID" : "j755", "Timepoint" : "10", "Tumor Volume" : "48.16706083" , "Metastatic": "0"},
{"Unique Mouse ID" : "j913", "Timepoint" : "10", "Tumor Volume" : "44.49716216", "Metastatic" : "0"},{"Unique Mouse ID" : "j984", "Timepoint" : "10", "Tumor Volume" : "50.14108401" , "Metastatic": "1"},
{"Unique Mouse ID" : "j989", "Timepoint" : "10", "Tumor Volume" : "46.34383237" , "Metastatic": "1"},{"Unique Mouse ID" : "k210", "Timepoint" : "10", "Tumor Volume" : "49.37993231", "Metastatic" : "0"},
{"Unique Mouse ID" : "k382", "Timepoint" : "10", "Tumor Volume" : "50.18096763" , "Metastatic": "1"},{"Unique Mouse ID" : "k403", "Timepoint" : "10", "Tumor Volume" : "35.01427146" , "Metastatic": "1"},
{"Unique Mouse ID" : "k483", "Timepoint" : "10", "Tumor Volume" : "50.29604123", "Metastatic" : "1"},{"Unique Mouse ID" : "k510", "Timepoint" : "10", "Tumor Volume" : "47.6582498" , "Metastatic": "1"},
{"Unique Mouse ID" : "k603", "Timepoint" : "10", "Tumor Volume" : "46.60694676" , "Metastatic": "0"},{"Unique Mouse ID" : "k754", "Timepoint" : "10", "Tumor Volume" : "49.74611666", "Metastatic" : "0"},
{"Unique Mouse ID" : "k804", "Timepoint" : "10", "Tumor Volume" : "54.48451945" , "Metastatic": "0"},{"Unique Mouse ID" : "k862", "Timepoint" : "10", "Tumor Volume" : "50.52355007" , "Metastatic": "1"},
{"Unique Mouse ID" : "k894", "Timepoint" : "10", "Tumor Volume" : "49.27287011", "Metastatic" : "1"},{"Unique Mouse ID" : "l264", "Timepoint" : "10", "Tumor Volume" : "50.6595809" , "Metastatic": "0"},
{"Unique Mouse ID" : "l471", "Timepoint" : "10", "Tumor Volume" : "48.18206306", "Metastatic" : "0"},{"Unique Mouse ID" : "l490", "Timepoint" : "10", "Tumor Volume" : "47.25960594" , "Metastatic": "1"},  

{"Unique Mouse ID" : "l509", "Timepoint" : "10", "Tumor Volume" : "46.75907363" , "Metastatic": "0"},{"Unique Mouse ID" : "l558", "Timepoint" : "10", "Tumor Volume" : "46.78453491", "Metastatic" : "0"},
{"Unique Mouse ID" : "l661", "Timepoint" : "10", "Tumor Volume" : "49.68361956", "Metastatic": "0"},{"Unique Mouse ID" : "l700", "Timepoint" : "10", "Tumor Volume" : "47.01356652" , "Metastatic": "1"},
{"Unique Mouse ID" : "l725", "Timepoint" : "10", "Tumor Volume" : "50.82391154", "Metastatic" : "2"},{"Unique Mouse ID" : "l733", "Timepoint" : "10", "Tumor Volume" : "48.35495154" , "Metastatic": "0"},
{"Unique Mouse ID" : "l872", "Timepoint" : "0", "Tumor Volume" : "45" , "Metastatic": "0"},{"Unique Mouse ID" : "l897", "Timepoint" : "10", "Tumor Volume" : "46.15473721", "Metastatic" : "0"},
{"Unique Mouse ID" : "m133", "Timepoint" : "10", "Tumor Volume" : "47.50333803" , "Metastatic": "0"},{"Unique Mouse ID" : "m269", "Timepoint" : "10", "Tumor Volume" : "50.86013006" , "Metastatic": "0"},
{"Unique Mouse ID" : "m331", "Timepoint" : "10", "Tumor Volume" : "47.64687735", "Metastatic" : "1"},{"Unique Mouse ID" : "m456", "Timepoint" : "10", "Tumor Volume" : "43.74822357" , "Metastatic": "0"},
{"Unique Mouse ID" : "m550", "Timepoint" : "10", "Tumor Volume" : "50.54803457" , "Metastatic": "2"},{"Unique Mouse ID" : "m601", "Timepoint" : "10", "Tumor Volume" : "36.82536664", "Metastatic" : "1"},
{"Unique Mouse ID" : "m650", "Timepoint" : "10", "Tumor Volume" : "50.96899763" , "Metastatic": "1"},{"Unique Mouse ID" : "m756", "Timepoint" : "0", "Tumor Volume" : "45" , "Metastatic": "0"},
{"Unique Mouse ID" : "m957", "Timepoint" : "10", "Tumor Volume" : "46.4145177", "Metastatic" : "1"},{"Unique Mouse ID" : "n304", "Timepoint" : "10", "Tumor Volume" : "47.20125097" , "Metastatic": "0"},
{"Unique Mouse ID" : "n364", "Timepoint" : "10", "Tumor Volume" : "40.3751382", "Metastatic" : "0"},{"Unique Mouse ID" : "n482", "Timepoint" : "0", "Tumor Volume" : "45" , "Metastatic": "0"},  
 
{"Unique Mouse ID" : "n630", "Timepoint" : "0", "Tumor Volume" : "45" , "Metastatic": "0"},{"Unique Mouse ID" : "n671", "Timepoint" : "10", "Tumor Volume" : "51.03935653", "Metastatic" : "0"},
{"Unique Mouse ID" : "n678", "Timepoint" : "10", "Tumor Volume" : "49.14570866", "Metastatic": "1"},{"Unique Mouse ID" : "n763", "Timepoint" : "10", "Tumor Volume" : "46.81731526" , "Metastatic": "1"},
{"Unique Mouse ID" : "n923", "Timepoint" : "10", "Tumor Volume" : "48.79194986", "Metastatic" : "1"},{"Unique Mouse ID" : "n967", "Timepoint" : "10", "Tumor Volume" : "47.47172327" , "Metastatic": "1"},
{"Unique Mouse ID" : "o287", "Timepoint" : "10", "Tumor Volume" : "47.36020084" , "Metastatic": "1"},{"Unique Mouse ID" : "o302", "Timepoint" : "10", "Tumor Volume" : "49.70144989", "Metastatic" : "0"},
{"Unique Mouse ID" : "o331", "Timepoint" : "10", "Tumor Volume" : "50.12845481" , "Metastatic": "1"},{"Unique Mouse ID" : "o523", "Timepoint" : "10", "Tumor Volume" : "47.0810859" , "Metastatic": "1"},
{"Unique Mouse ID" : "o562", "Timepoint" : "10", "Tumor Volume" : "47.14767002", "Metastatic" : "1"},{"Unique Mouse ID" : "o725", "Timepoint" : "10", "Tumor Volume" : "48.199452" , "Metastatic": "0"},
{"Unique Mouse ID" : "o795", "Timepoint" : "10", "Tumor Volume" : "51.1237037" , "Metastatic": "1"},{"Unique Mouse ID" : "o809", "Timepoint" : "10", "Tumor Volume" : "48.6707318", "Metastatic" : "0"},
{"Unique Mouse ID" : "o813", "Timepoint" : "0", "Tumor Volume" : "45" , "Metastatic": "0"},{"Unique Mouse ID" : "o848", "Timepoint" : "0", "Tumor Volume" : "45" , "Metastatic": "0"},
{"Unique Mouse ID" : "o926", "Timepoint" : "10", "Tumor Volume" : "47.56567364", "Metastatic" : "1"},{"Unique Mouse ID" : "o973", "Timepoint" : "10", "Tumor Volume" : "48.24579043" , "Metastatic": "0"},
{"Unique Mouse ID" : "p136", "Timepoint" : "10", "Tumor Volume" : "50.90789028", "Metastatic" : "0"},{"Unique Mouse ID" : "p189", "Timepoint" : "10", "Tumor Volume" : "51.58216168" , "Metastatic": "2"},  

{"Unique Mouse ID" : "p310", "Timepoint" : "10", "Tumor Volume" : "48.66560668" , "Metastatic": "1"},{"Unique Mouse ID" : "p387", "Timepoint" : "10", "Tumor Volume" : "53.36296294", "Metastatic" : "0"},
{"Unique Mouse ID" : "p438", "Timepoint" : "10", "Tumor Volume" : "50.51749789", "Metastatic": "0"},{"Unique Mouse ID" : "p981", "Timepoint" : "10", "Tumor Volume" : "47.54584585" , "Metastatic": "0"},
{"Unique Mouse ID" : "q119", "Timepoint" : "10", "Tumor Volume" : "51.23660557", "Metastatic" : "0"},{"Unique Mouse ID" : "q132", "Timepoint" : "10", "Tumor Volume" : "47.95384377" , "Metastatic": "2"},
{"Unique Mouse ID" : "q483", "Timepoint" : "10", "Tumor Volume" : "47.8391005" , "Metastatic": "1"},{"Unique Mouse ID" : "q511", "Timepoint" : "10", "Tumor Volume" : "50.31164687", "Metastatic" : "0"},
{"Unique Mouse ID" : "q582", "Timepoint" : "10", "Tumor Volume" : "47.01357514" , "Metastatic": "1"},{"Unique Mouse ID" : "q597", "Timepoint" : "10", "Tumor Volume" : "42.53798598" , "Metastatic": "0"},
{"Unique Mouse ID" : "q610", "Timepoint" : "10", "Tumor Volume" : "44.99148471", "Metastatic" : "0"},{"Unique Mouse ID" : "q633", "Timepoint" : "10", "Tumor Volume" : "49.00186559" , "Metastatic": "0"},
{"Unique Mouse ID" : "q787", "Timepoint" : "10", "Tumor Volume" : "48.59386234" , "Metastatic": "1"},{"Unique Mouse ID" : "r107", "Timepoint" : "10", "Tumor Volume" : "49.18601052", "Metastatic" : "0"},
{"Unique Mouse ID" : "r554", "Timepoint" : "10", "Tumor Volume" : "39.0054935" , "Metastatic": "2"},{"Unique Mouse ID" : "r604", "Timepoint" : "10", "Tumor Volume" : "48.78655957" , "Metastatic": "1"},
{"Unique Mouse ID" : "r701", "Timepoint" : "10", "Tumor Volume" : "49.65459636", "Metastatic" : "0"},{"Unique Mouse ID" : "r811", "Timepoint" : "10", "Tumor Volume" : "39.453903" , "Metastatic": "0"},
{"Unique Mouse ID" : "r850", "Timepoint" : "10", "Tumor Volume" : "48.51509085", "Metastatic" : "1"},{"Unique Mouse ID" : "r921", "Timepoint" : "10", "Tumor Volume" : "42.71192694" , "Metastatic": "0"},

{"Unique Mouse ID" : "r944", "Timepoint" : "10", "Tumor Volume" : "46.54429202" , "Metastatic": "0"},{"Unique Mouse ID" : "s121", "Timepoint" : "10", "Tumor Volume" : "49.04883479", "Metastatic" : "1"},
{"Unique Mouse ID" : "s141", "Timepoint" : "10", "Tumor Volume" : "47.23569156", "Metastatic": "0"},{"Unique Mouse ID" : "s152", "Timepoint" : "10", "Tumor Volume" : "52.1816442" , "Metastatic": "2"},
{"Unique Mouse ID" : "s166", "Timepoint" : "10", "Tumor Volume" : "49.00012468", "Metastatic" : "0"},{"Unique Mouse ID" : "s185", "Timepoint" : "10", "Tumor Volume" : "37.61494768" , "Metastatic": "0"},
{"Unique Mouse ID" : "s187", "Timepoint" : "10", "Tumor Volume" : "48.14635121" , "Metastatic": "1"},{"Unique Mouse ID" : "s337", "Timepoint" : "10", "Tumor Volume" : "47.8944415", "Metastatic" : "0"},
{"Unique Mouse ID" : "s508", "Timepoint" : "10", "Tumor Volume" : "34.8509979" , "Metastatic": "0"},{"Unique Mouse ID" : "s565", "Timepoint" : "10", "Tumor Volume" : "52.7775271" , "Metastatic": "0"},
{"Unique Mouse ID" : "s619", "Timepoint" : "0", "Tumor Volume" : "45", "Metastatic" : "0"},{"Unique Mouse ID" : "s710", "Timepoint" : "10", "Tumor Volume" : "43.68802627" , "Metastatic": "0"},
{"Unique Mouse ID" : "t198", "Timepoint" : "10", "Tumor Volume" : "49.00080978" , "Metastatic": "1"},{"Unique Mouse ID" : "t451", "Timepoint" : "0", "Tumor Volume" : "48.95791906", "Metastatic" : "0"},
{"Unique Mouse ID" : "t565", "Timepoint" : "10", "Tumor Volume" : "46.74900552" , "Metastatic": "0"},{"Unique Mouse ID" : "t718", "Timepoint" : "10", "Tumor Volume" : "46.39268805" , "Metastatic": "1"},
{"Unique Mouse ID" : "t724", "Timepoint" : "10", "Tumor Volume" : "50.70389965", "Metastatic" : "0"},{"Unique Mouse ID" : "t994", "Timepoint" : "10", "Tumor Volume" : "52.6141635" , "Metastatic": "1"},
{"Unique Mouse ID" : "u149", "Timepoint" : "10", "Tumor Volume" : "47.40483439", "Metastatic" : "0"},{"Unique Mouse ID" : "u153", "Timepoint" : "0", "Tumor Volume" : "45" , "Metastatic": "0"},
 
{"Unique Mouse ID" : "u327", "Timepoint" : "10", "Tumor Volume" : "49.23525948" , "Metastatic": "0"},{"Unique Mouse ID" : "u364", "Timepoint" : "10", "Tumor Volume" : "46.56841719", "Metastatic" : "2"},
{"Unique Mouse ID" : "u946", "Timepoint" : "10", "Tumor Volume" : "46.73050592", "Metastatic": "1"},{"Unique Mouse ID" : "v199", "Timepoint" : "0", "Tumor Volume" : "45" , "Metastatic": "0"},
{"Unique Mouse ID" : "v339", "Timepoint" : "0", "Tumor Volume" : "45", "Metastatic" : "0"},{"Unique Mouse ID" : "v409", "Timepoint" : "10", "Tumor Volume" : "50.64903842" , "Metastatic": "1"},
{"Unique Mouse ID" : "v603", "Timepoint" : "10", "Tumor Volume" : "47.8305568" , "Metastatic": "0"},{"Unique Mouse ID" : "v719", "Timepoint" : "10", "Tumor Volume" : "51.49705412", "Metastatic" : "1"},
{"Unique Mouse ID" : "v764", "Timepoint" : "10", "Tumor Volume" : "48.18900062" , "Metastatic": "1"},{"Unique Mouse ID" : "v766", "Timepoint" : "10", "Tumor Volume" : "50.36310988" , "Metastatic": "1"},
{"Unique Mouse ID" : "v835", "Timepoint" : "10", "Tumor Volume" : "48.96591797", "Metastatic" : "0"},{"Unique Mouse ID" : "v923", "Timepoint" : "10", "Tumor Volume" : "39.84822328" , "Metastatic": "0"},
{"Unique Mouse ID" : "v989", "Timepoint" : "10", "Tumor Volume" : "52.61468889" , "Metastatic": "1"},{"Unique Mouse ID" : "v991", "Timepoint" : "10", "Tumor Volume" : "52.6449057", "Metastatic" : "1"},
{"Unique Mouse ID" : "w140", "Timepoint" : "0", "Tumor Volume" : "45" , "Metastatic": "0"},{"Unique Mouse ID" : "w150", "Timepoint" : "10", "Tumor Volume" : "39.95234669" , "Metastatic": "0"},
{"Unique Mouse ID" : "w151", "Timepoint" : "10", "Tumor Volume" : "46.50147609", "Metastatic" : "1"},{"Unique Mouse ID" : "w167", "Timepoint" : "10", "Tumor Volume" : "51.82640965" , "Metastatic": "1"},
{"Unique Mouse ID" : "w193", "Timepoint" : "10", "Tumor Volume" : "48.34655046", "Metastatic" : "0"},{"Unique Mouse ID" : "w350", "Timepoint" : "10", "Tumor Volume" : "48.89955238" , "Metastatic": "0"},    

{"Unique Mouse ID" : "w422", "Timepoint" : "10", "Tumor Volume" : "49.93597024" , "Metastatic": "0"},{"Unique Mouse ID" : "w540", "Timepoint" : "10", "Tumor Volume" : "47.45906658", "Metastatic" : "1"},
{"Unique Mouse ID" : "w575", "Timepoint" : "10", "Tumor Volume" : "50.13595547", "Metastatic": "1"},{"Unique Mouse ID" : "w584", "Timepoint" : "10", "Tumor Volume" : "47.29850794" , "Metastatic": "0"},
{"Unique Mouse ID" : "w678", "Timepoint" : "0", "Tumor Volume" : "45", "Metastatic" : "0"},{"Unique Mouse ID" : "w697", "Timepoint" : "10", "Tumor Volume" : "48.925056" , "Metastatic": "2"},
{"Unique Mouse ID" : "w746", "Timepoint" : "0", "Tumor Volume" : "45" , "Metastatic": "0"},{"Unique Mouse ID" : "w914", "Timepoint" : "10", "Tumor Volume" : "43.23196275", "Metastatic" : "0"},
{"Unique Mouse ID" : "x111", "Timepoint" : "10", "Tumor Volume" : "49.12296898" , "Metastatic": "1"},{"Unique Mouse ID" : "x209", "Timepoint" : "10", "Tumor Volume" : "48.92989543" , "Metastatic": "0"},
{"Unique Mouse ID" : "x226", "Timepoint" : "0", "Tumor Volume" : "45", "Metastatic" : "0"},{"Unique Mouse ID" : "x264", "Timepoint" : "10", "Tumor Volume" : "47.88712765" , "Metastatic": "1"},
{"Unique Mouse ID" : "x336", "Timepoint" : "0", "Tumor Volume" : "45" , "Metastatic": "0"},{"Unique Mouse ID" : "x401", "Timepoint" : "10", "Tumor Volume" : "39.11389068", "Metastatic" : "0"},
{"Unique Mouse ID" : "x402", "Timepoint" : "10", "Tumor Volume" : "46.88696249" , "Metastatic": "1"},{"Unique Mouse ID" : "x581", "Timepoint" : "10", "Tumor Volume" : "49.06702788" , "Metastatic": "1"},
{"Unique Mouse ID" : "x613", "Timepoint" : "10", "Tumor Volume" : "46.8181759", "Metastatic" : "0"},{"Unique Mouse ID" : "x773", "Timepoint" : "10", "Tumor Volume" : "47.18920597" , "Metastatic": "2"},
{"Unique Mouse ID" : "x822", "Timepoint" : "10", "Tumor Volume" : "48.98371668", "Metastatic" : "1"},{"Unique Mouse ID" : "x930", "Timepoint" : "10", "Tumor Volume" : "50.26069441" , "Metastatic": "0"}, 
  
{"Unique Mouse ID" : "y163", "Timepoint" : "10", "Tumor Volume" : "49.1123991" , "Metastatic": "1"},{"Unique Mouse ID" : "y260", "Timepoint" : "10", "Tumor Volume" : "48.08180678", "Metastatic" : "1"},
{"Unique Mouse ID" : "y449", "Timepoint" : "10", "Tumor Volume" : "46.37809248", "Metastatic": "0"},{"Unique Mouse ID" : "y478", "Timepoint" : "10", "Tumor Volume" : "52.28893409" , "Metastatic": "1"},
{"Unique Mouse ID" : "y601", "Timepoint" : "0", "Tumor Volume" : "45", "Metastatic" : "0"},{"Unique Mouse ID" : "y769", "Timepoint" : "10", "Tumor Volume" : "48.01516261" , "Metastatic": "1"},
{"Unique Mouse ID" : "y793", "Timepoint" : "10", "Tumor Volume" : "41.63001026" , "Metastatic": "1"},{"Unique Mouse ID" : "y865", "Timepoint" : "10", "Tumor Volume" : "49.52273955", "Metastatic" : "1"},
{"Unique Mouse ID" : "z234", "Timepoint" : "0", "Tumor Volume" : "45" , "Metastatic": "0"},{"Unique Mouse ID" : "z314", "Timepoint" : "0", "Tumor Volume" : "45" , "Metastatic": "0"},
{"Unique Mouse ID" : "z435", "Timepoint" : "10", "Tumor Volume" : "48.71066147", "Metastatic" : "0"},{"Unique Mouse ID" : "z578", "Timepoint" : "10", "Tumor Volume" : "42.95211843" , "Metastatic": "0"},
{"Unique Mouse ID" : "z581", "Timepoint" : "10", "Tumor Volume" : "50.47875016" , "Metastatic": "2"},{"Unique Mouse ID" : "z795", "Timepoint" : "10", "Tumor Volume" : "48.0308039", "Metastatic" : "0"},
{"Unique Mouse ID" : "z969", "Timepoint" : "10", "Tumor Volume" : "52.65608148" , "Metastatic": "1"},
    
])

mouse_id_df
# Out:
#     Unique Mouse ID Timepoint Tumor Volume Metastatic
# 0              a203        10   51.8524372          1
# 1              a251        10  48.59117901          1
# 2              a262        10  49.59518129          1
# 3              a275        10  47.37134328          0
# 4              a366        10  53.52399007          0
# ..              ...       ...          ...        ...
# 232            z435        10  48.71066147          0
# 233            z578        10  42.95211843          0
# 234            z581        10  50.47875016          2
# 235            z795        10   48.0308039          0
# 236            z969        10  52.65608148          1
#
# [237 rows x 4 columns]

# %%
import pandas as pd 
# Create a DataFrame from a list of dictionaries.
tumorpoints_df = pd.DataFrame([
    {"Drug": "Capomulin", "Average Tumorvolume" : "37.33288394"}, 
    {"Drug": "Ceftamin", "Average Tumorvolume": "57.75397683"}, 
    {"Drug": "Infubinol", "Average Tumorvolume": "58.17824579"},
    {"Drug": "Ramicane", "Average Tumorvolume": "36.19139043"}
])
tumorpoints_df
# Out:
#         Drug Average Tumorvolume
# 0  Capomulin         37.33288394
# 1   Ceftamin         57.75397683
# 2  Infubinol         58.17824579
# 3   Ramicane         36.19139043

# %%
import pandas as pd
import numpy as np

# %%
#Create a DataFrame from a list of dictionaries. 
#Greatest Last Timepoint for each mouse 
totaltumorvolume_df = pd.DataFrame ([
    {"Drug" : "Capomulin", "Tumor Volume" : ("45.65133131", "37.95035546" , "30.48598484", "36.35685121", "40.1592203",
"47.68596303", "37.31184577", "38.1251644", "38.75326548", "41.48300765", "38.84687569", "28.43096411", "45", "46.53920617",
"32.37735684", "41.58152074", "23.34359787", "40.72857787", "34.45529799", "31.02392294", "40.65812366", "39.95234669",
"36.04104736", "28.48403281", "31.8962384")},
    {"Drug" : "Certamin", "Tumor Volume" : ("62.99935619", "45", "56.05774909", "55.74282869", "48.72207785", "47.7846818",
"61.84902336", "68.92318457", "67.74866174", "57.91838132", "46.78453491", "59.85195552", "64.29983003", "59.74190064",
"61.43389223", "64.19234114", "45", "52.92534846", "45", "67.52748237", "45", "64.63494887", "61.38666032", "68.59474498",
"64.72983655")}, 
    {"Drug" : "Infubinol", "Tumor Volume" : ("67.97341878", "65.52574285", "57.03186187", "66.08306589", "72.2267309",
"36.3213458", "60.96971133", "62.43540402", "60.91876652", "67.28962147", "66.19691151", "62.11727887",
"47.01036401", "60.16518046", "55.62942846", "45.69933088", "54.65654872", "55.65068132", "46.25011212", "54.04860769",
"51.54243058", "50.00513807", "58.26844248", "67.68556862", "62.75445141")},
    {"Drug" : "Ramicane", "Tumor Volume" : ("38.4076183", "43.0475426", "38.81036633", "32.97852192", "38.34200823",
"33.39765251", "37.31123552", "40.65900627", "29.12847181", "33.56240217", "36.37451039", "31.56046955",
"36.13485243", "22.05012627", "30.56462509", "31.09533505", "45.22086888", "36.56165229", "37.22565033", "43.41938077",
"30.27623175", "40.66771292", "43.16637266", "44.18345092", "30.63869575")}
])
totaltumorvolume_df
# Out:
#         Drug                                       Tumor Volume
# 0  Capomulin  (45.65133131, 37.95035546, 30.48598484, 36.356...
# 1   Certamin  (62.99935619, 45, 56.05774909, 55.74282869, 48...
# 2  Infubinol  (67.97341878, 65.52574285, 57.03186187, 66.083...
# 3   Ramicane  (38.4076183, 43.0475426, 38.81036633, 32.97852...

# %%
# %matplotlib notebook

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
#Creating the dataset
data = {"s185" : "45.65133131", "x401" : "51.61838657", "m601" : "51.93995092", "f966" : "38.08737318", "u364" : "47.6643871", "y793" : "64.14987077", 
        "r554" : "45", "m957" : "60.56790371", "t565" : "45", "i738" : "53.67719253", "w914" : "54.44303502", "g288" : "39.71723589", 
        "l897" : "32.97852192", "b742" : "57.01331331", "b128" : "65.52574285", "j246" : "57.92849897", "j119" : "56.20104104", 
        "w150" : "41.99922813", "v923" : "69.96961645", "g316" : "38.4076183", "s710" : "37.96764437", "l509" : "46.38071258", "r944" : "53.40166738", 
        "i557" : "46.40914339", "r157" : "72.25596306"}
mouseid = list(data.keys())
mediantimepoint = list(data.values())

fig = plt.figure(figsize = (30, 5))

# creating the bar plot
plt.bar(mouseid, mediantimepoint, color ='maroon', 
        width = 0.5)

plt.xlabel("Unique Mouse ID")
plt.ylabel("Median Timepoint")
plt.title("Drug Capomulin")
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="3000">

# %%
# %matplotlib notebook

# %%
import matplotlib.pyplot as plt 
import numpy as np

# %%
#Creating the dataset
data  = {"Capomulin" : "25", "Ceftamin" : "24", "Infubinol" : "24", "Ketapril" : "24", "Naftisol" : "24", "Placebo" : "24", 
        "Propriva" : "24", "Ramicane" : "24", "Stelasyn" : "23", "Zoniferol" : "24" }
Drugtested = list(data.keys())
numberofMouseID = list(data.values())

fig = plt.figure(figsize = (30, 5))

# creating the bar plot
plt.bar(Drugtested, numberofMouseID, color ='maroon', 
        width = 0.5)

plt.xlabel("Drug tested")
plt.ylabel("Number of Unique Mouse ID")
plt.title("Drugs and total Mouse ID")
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="3000">

# %%
#Creating the dataset
data  = {"Capomulin" : "25", "Ceftamin" : "24", "Infubinol" : "24", "Ketapril" : "24", "Naftisol" : "24", "Placebo" : "24", 
        "Propriva" : "24", "Ramicane" : "24", "Stelasyn" : "23", "Zoniferol" : "24" }
Drugtested = list(data.keys())
numberofMouseID = list(data.values())

fig = plt.figure(figsize = (30, 5))

# creating the bar plot
plt.bar(Drugtested, numberofMouseID, color ='green', 
        width = 0.5)

plt.xlabel("Drug tested")
plt.ylabel("Number of Unique Mouse ID")
plt.title("Drugs over total Mouse IDs")
plt.show()

# %%
#Import libraries 
from matplotlib import pyplot as plt
import numpy as np

#Creating dataset 
Sex = ['Female', 'Male']

Data = [124, 125]

# Creating plot
fig = plt.figure(figsize =(7, 6))
plt.pie(Data, labels = Sex)
ax.set_title('Total Sex used in Study')
explode = (0.5, 0.7)
fig, ax = plt.subplots()
ax.pie(Data,
       explode=explode,
       autopct='%1.1f%%',
       shadow=True,
       startangle=90)
ax.axis('equal')  # Equal aspect ratio ensures the pie chart is circular.
ax.set_title('Total Sex used in study')



plt.show()
# show plot
plt.show()

# %%
#Capomulin Mouse ID 'b128'
#Timepoints : 0, 5, 10, 15, 20, 25, 30, 35, 40
#Against tumor volume = 45, 45.65133131, 43.2708519, 43.78489343, 42.731552, 43.26214483, 40.60533486, 37.96764437, 38.3797259, 38.98287774

#Mouse weight for Capomulin : 22, 21, 17, 19, 22, 24, 20, 23, 21, 19, 17, 19, 25, 17, 25, 17, 23, 17, 17, 21, 23, 21, 15, 17
#Against tumor volume =

# %%
# Import libraries
import matplotlib.pyplot as plt
import numpy as np

# Creating dataset

Capomulin = (45.65133131, 37.95035546 , 30.48598484, 36.35685121, 40.1592203,
47.68596303, 37.31184577, 38.1251644, 38.75326548, 41.48300765, 38.84687569, 28.43096411, 45, 46.53920617,
32.37735684, 41.58152074, 23.34359787, 40.72857787, 34.45529799, 31.02392294, 40.65812366, 39.95234669,
36.04104736, 28.48403281, 31.8962384)
Certamin = (62.99935619, 45, 56.05774909, 55.74282869, 48.72207785, 47.7846818,
61.84902336, 68.92318457, 67.74866174, 57.91838132, 46.78453491, 59.85195552, 64.29983003, 59.74190064,
61.43389223, 64.19234114, 45, 52.92534846, 45, 67.52748237, 45, 64.63494887, 61.38666032, 68.59474498,
64.72983655)
Infubinol = (67.97341878, 65.52574285, 57.03186187, 66.08306589, 72.2267309,
36.3213458, 60.96971133, 62.43540402, 60.91876652, 67.28962147, 66.19691151, 62.11727887,
47.01036401, 60.16518046, 55.62942846, 45.69933088, 54.65654872, 55.65068132, 46.25011212, 54.04860769,
51.54243058, 50.00513807, 58.26844248, 67.68556862, 62.75445141)
Ramicane = (38.4076183, 43.0475426, 38.81036633, 32.97852192, 38.34200823,
33.39765251, 37.31123552, 40.65900627, 29.12847181, 33.56240217, 36.37451039, 31.56046955,
36.13485243, 22.05012627, 30.56462509, 31.09533505, 45.22086888, 36.56165229, 37.22565033, 43.41938077,
30.27623175, 40.66771292, 43.16637266, 44.18345092, 30.63869575)
data = [data_1, data_2, data_3, data_4]
 
fig = plt.figure(figsize =(10, 7))
 
# Creating axes instance
ax = fig.add_axes([0, 0, 1, 1])
 
# Creating plot
bp = ax.boxplot(data)

fig = plt.figure(figsize =(10, 7))
ax = fig.add_subplot(111)
 
# Creating axes instance
bp = ax.boxplot(data, patch_artist = True,
                notch ='True', vert = 0)

colors = ['#0000FF', '#00FF00', 
          '#FFFF00', '#FF00FF']
 
for patch, color in zip(bp['boxes'], colors):
    patch.set_facecolor(color)
    
# changing color and linewidth of
# whiskers
for whisker in bp['whiskers']:
    whisker.set(color ='#8B008B',
                linewidth = 1.5,
                linestyle =":")
 
# changing color and linewidth of
# caps
for cap in bp['caps']:
    cap.set(color ='#8B008B',
            linewidth = 2)
 
# changing color and linewidth of
# medians
for median in bp['medians']:
    median.set(color ='red',
               linewidth = 3)
 
# changing style of fliers
for flier in bp['fliers']:
    flier.set(marker ='D',
              color ='#e7298a',
              alpha = 0.5)
     
# x-axis labels
ax.set_yticklabels(['data_1', 'data_2', 
                    'data_3', 'data_4'])
 
# Adding title 
plt.title("Customized box plot")
 
# Removing top axes and right axes
# ticks
ax.get_xaxis().tick_bottom()
ax.get_yaxis().tick_left()
     
# show plot
plt.show()

# show plot
plt.show()

# %%
import matplotlib.pyplot as plt 
import numpy as np 
  
  
x = np.array([0, 5, 10, 15, 20, 25, 30, 35, 40]) 
y = x = y
  
plt.plot(x, y) 
plt.xlabel("Timepoint") 
plt.ylabel("Tumor Volume") 
plt.title("Capomulin, Mouse ID 'b128'") 
plt.show()  # show first chart 
  
# The figure() function helps in creating a 
# new figure that can hold a new chart in it. 
plt.figure() 
x1 = [45, 45.65133131, 43.2708519, 43.78489343, 42.731552, 43.26214483, 40.60533486, 37.96764437, 38.3797259, 38.98287774] 
y1 = [45, 45.65133131, 43.2708519, 43.78489343, 42.731552, 43.26214483, 40.60533486, 37.96764437, 38.3797259, 38.98287774] 
plt.plot(x1, y1, '-.') 
  
# Show another chart with '-' dotted line 
plt.show()

# %%
import matplotlib.pyplot as plt 
import numpy as np 
  
  
x = np.array([22, 21, 17, 19, 22, 24, 20, 23, 21, 19, 17, 19, 25, 17, 25, 17, 23, 17, 17, 21, 23, 21, 15, 17]) 
y = x = y
  
plt.scatter(x, y) 
plt.xlabel("Mouse Weight") 
plt.ylabel("Tumor Volume") 
plt.title("Capomulin") 
plt.show()  # show first chart 
  
# The figure() function helps in creating a 
# new figure that can hold a new chart in it. 
plt.figure() 
x1 = [45, 45.65133131, 43.2708519, 43.78489343, 42.731552, 43.26214483, 40.60533486, 37.96764437, 38.3797259, 38.98287774] 
y1 = [45, 45.65133131, 43.2708519, 43.78489343, 42.731552, 43.26214483, 40.60533486, 37.96764437, 38.3797259, 38.98287774] 
plt.plot(x1, y1, '-.') 
  
# Show another chart with '-' dotted line 
plt.show()
